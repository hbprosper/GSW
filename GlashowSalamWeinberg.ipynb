# %% [markdown]
# ## Glashow-Salam-Weinberg Model
#
# ### Introduction
#
# In 1934, Enrico Fermi proposed the following 4-fermion model
# \begin{align*}
#     \frac{G_F}{\sqrt{2}}(\overline{\psi}_e \gamma^\mu \psi_{\overline{\nu}})(\overline{\psi}_p \gamma_\mu \psi_n),
# \end{align*}
# to describe $\beta$-decay processes such as $n \rightarrow p + e^- + \overline{\nu}_e$. The quantity $\overline{\psi} \equiv \psi^\dagger \gamma^0$ is called the Dirac conjugate of the spinor $\psi$, where the operator $^\dagger$ is the Hermitian conjugate, i.e., the transpose and complex conjugate and $\gamma^\mu$ are $4 \times 4$ matrices defined by the anti-commutation relations $\gamma^\mu \gamma^\nu + \gamma^\nu \gamma^\mu = 2  g^{\mu\nu}$, where $g^{\mu\nu}$ is the metric tensor of
# special relativity.
# $G_F$ is called the Fermi constant.
#
# Fermi assumed that $\beta$-decay involved vector currents, $\overline{\psi} \gamma^\mu \psi$, but in 1956 T. D. Lee and C. N. Yang noted that no experiment had been
# performed to test the assumption of parity invariance, that is, the invariance of particle interactions with respect to a reflection in a mirror. They suggested that certain experimental puzzles could be explained if parity was not conserved in the weak interactions. Furthermore, Lee and Yang suggested experiments to test this hypothesis. Shortly thereafter, Chien-Shiung Wu performed the experiment (see https://en.wikipedia.org/wiki/Wu_experiment) and confirmed the violation of parity invariance. The following year, Lee and Yang won the Nobel Prize in Physics. A year later, in 1958, Robert Marshak and his student George Sudarshan developed the vector axial-vector theory (V-A) of the weak interactions, which Richard Feynman and Murray Gell-Mann developed further.
#
# We do not know why the weak interactions violate parity conservation, in particular, why they involve both vector $\overline{\psi} \gamma^\mu \psi$ and axial-vector $\overline{\psi} \gamma^\mu \gamma^5 \psi$ currents, where
# $\gamma^5 \equiv i \gamma^0 \gamma^1 \gamma^2 \gamma^3$. Now that we have a better understanding of the weak interactions, however, it would be simpler to say that the weak interactions treat left and right-handed fields differently. But, the V-A jargon has stuck.
#
#
# The Glashow-Salam-Weinberg (GSW) Langrangian (really a Lagrangian density) is built using the fields below for the 1st generation of leptons and quarks:
#
# \begin{align*}
# L & = \begin{pmatrix} \nu_L \\ e_L \end{pmatrix},\quad
# e_R, \\
# Q & = \begin{pmatrix} u_L \\ d_L \end{pmatrix},\quad
# u_R, \quad d_R, \\
#     & \textrm{where } \\
# P_L & = \frac{1}{2}(1 - \gamma^5),\\
# P_R & = \frac{1}{2}(1 + \gamma^5) \\
#     & \textrm{are projection operators that split a} \\
#     & \textrm{fermion field into its left and right components} \\
# \psi_{L,\, R} & = P_{L,\, R}  \, \psi ,
# \end{align*}
# which implies $\psi = \psi_L + \psi_R$.
# Note the absence, in this model, of the field $\nu_R$.
#
#
# The GSW model, inspired by the highly successful quantum field theory of quantum electrodynamics (QED) and the quantum field theories developed by Yang and Mills is defined by the Langrangian,
#
# \begin{align*}
#     {\cal L} & = \overline{L} i \gamma^\mu \left(\partial_\mu \mathbf{1} + i g_1 \frac{Y_L}{2} B_\mu \mathbf{1} + i g_2 \frac{\boldsymbol{\tau}}{2} \cdot \mathbf{W}_\mu \right) L\\
#     & + \overline{Q} i \gamma^\mu \left(\partial_\mu \mathbf{1}+ i g_1 \frac{Y_L^Q}{2}B_\mu \mathbf{1} + i g_2 \frac{\boldsymbol{\tau}}{2} \cdot \mathbf{W}_\mu\right) Q\\
#     & + \overline{e}_R i \gamma^\mu \left( \partial_\mu  + i Y_R g_1 \frac{Y_R}{2} B_\mu  \right) e_R\\
#     & + \overline{u}_R i \gamma^\mu \left( \partial_\mu + i  g_1 \frac{Y^u_R}{2} B_\mu  \right) u_R\\
#     & + \overline{d}_R i \gamma^\mu \left( \partial_\mu + i g_1 \frac{Y^d_R}{2} B_\mu  \right) d_R \\
#     & - \frac{1}{4} \mathbf{W}_{\mu\nu} \cdot \mathbf{W}^{\mu\nu}\\
#     & - \frac{1}{4} B_{\mu\nu} B^{\mu\nu},
# \end{align*}
# which explicitly treats left-handed and right-handed fields differently. The $Y$ symbols are constants called *hypercharges* that are chosen to obtain agreement with observations. The
# other symbols are:
# \begin{align*}
# \mathbf{1} & \textrm{ a $2 \times 2$ unit matrix}, \\
#     \boldsymbol{\tau} & \textrm{ are the Pauli matrices},\\
#     \textrm{and }& \textrm{the tensors $W_{\mu\nu}$ and $B_{\mu\nu}$
#     are given by}\\
#     \mathbf{W}_{\mu\nu} & = \partial_\mu \mathbf{W}_\nu- \partial_\nu \mathbf{W}_\mu - g_2 \, \mathbf{W}_\mu \times \mathbf{W}_\nu,\\
#     (\mathbf{W}_{\mu\nu})_i   & = (\partial_\mu \mathbf{W}_\nu)_i - (\partial_\nu \mathbf{W}_\mu)_i - g_2 \, \epsilon_{ijk} W^j_\mu W^k_\nu, \\
#     B_{\mu\nu} & = \partial_\mu B_\nu - \partial_\nu B_\mu \textrm{ and }\\
#     \mathbf{W}_\mu & = (W^1_\mu, \, W^2_\mu, \, W^3_\mu).
# \end{align*}
#
#
# The quantities enclosed in the first and second pair of parentheses in the Lagrangian are $2 \times 2$ matrices that act on the lepton and quark doublet fields $L$
# and $Q$, respectively, while the parentheses in the remaining fermionic terms enclose $1 \times 1$ matrices, that is, scalars, which act on the singlet fields $e_R$, $u_R$, and $d_R$, respectively. However, each field is  intrinsically a 4-component Lorentz object: a 4-component spinor in the case of the fermionic fields and a 4-vector in the case of the bosonic fields.
#
# In the GSW Lagrangian, the hypercharges are assigned specific numerical values. Therefore, the Lagrangian has only two free parameters, namely, the couplings $g_1$ and $g_2$.
#
# ### $SU(2) \otimes U(1)$ Gauge Invariance
# The GSW Lagrangian is invariant under
# the group $SU(2) \otimes U(1)$. The elements $U_2$ of  $SU(2)$ can be represented as the $2 \times 2$ matrices
#
# \begin{align*}
#     U & = \exp(i (\boldsymbol{\tau} \, / \, 2) \cdot \boldsymbol{\theta}(x)), \\\textrm{ while}\\
#     U & = \exp(i (Y \, / \, 2)  \, \alpha(x) ),
# \end{align*}
#
# represent the elements of $U(1)$. The $SU(2)$ elements are defined by three spacetime-dependent functions, $\mathbf{\theta}(x) = (\theta_1(x)$, $\theta_2(x)$, $\theta_3(x))$, each associated with group generators $T_1 = \tau_1 / 2$, $T_2 = \tau_2 / 2$, and $T_3 = \tau_3 /  2$, respectively, while the
# $U(1)$ elements are defined by a single function $\alpha(x)$ and a single generator $Y \, / \, 2$.
#
# Invariance under the group $SU(2) \otimes U(1)$ means that the following replacements
# leave the Lagrangian unchanged,
# \begin{align*}
# U \in \boldsymbol{SU(2)} \quad \quad \\
# L & \rightarrow U L, \quad Q \rightarrow U Q, \\
# e_R & \rightarrow e_R, \quad u_R \rightarrow u_R, \quad d_R \rightarrow d_R \\
# \frac{1}{2} \boldsymbol{\tau} \cdot \mathbf{W}_\mu & \rightarrow U \left( \frac{1}{2} \boldsymbol{\tau} \cdot \mathbf{W}_\mu  \right) U^{-1} - \frac{1}{i g_2} (\partial_\mu U) U^{-1}, \\
# B_\mu & \rightarrow B_\mu, \\
# U \in \boldsymbol{U(1)} \quad \quad \\
# L & \rightarrow U L, \quad Q \rightarrow U Q \\
# e_R & \rightarrow U e_R, \quad u_R \rightarrow U u_R, \quad
# d_R \rightarrow U d_R, \\
# \mathbf{W}_\mu & \rightarrow \mathbf{W}_\mu, \\
# B_\mu & \rightarrow U B_\mu U^{-1} - \frac{1}{i  g_1} (\partial_\mu U) U^{-1}.
# \end{align*}
#
# Notice the absence of mass terms such as $m \psi \psi$ and $M_B^2 B_\mu B^\mu$ in the Lagrangian. This is necessary because mass terms violate the imposed $SU(2) \otimes U(1)$ invariance.
#
# The model above was developed by Glashow in 1961. However, because it predicted zero mass for all bosonic fields (not just for the photon), it clearly did not accord with the absence of experimental evidence for a long-range weak nuclear force. But in 1964 a mechanism for introducing mass without violating gauge invariance was developed independently by Englert & Brout, by Higgs, and by Guralnik, Hagen & Kibble in a series of papers in that year. These papers were inspired by the work of the condensed matter theorist Phil Anderson. Much to the chagrin of the other theorists, the mechanism was referred to, by Steven Weinberg, as the Higgs mechanism and the name stuck. A more accurate name, though a bit of a mouthful, would be the *Anderson-Englert-Brout-Higgs-Guralnik-Hagen-Kibble* mechanism.
#
# In 1967, Salam and Weinberg, independently, showed how the Higgs mechanism can be used to correct the mass problem of the Glashow model. In addition, Weinberg introduced gauge invariant interactions between the Higgs field and the fermion fields that induced mass terms for the latter. Thus was born the __electroweak model__.
#
# It is usually argued that __local gauge__ invariance means that the phases of the quantum fields can be set to different values at different events in spacetime and that this makes sense because there is no reason why, for example, Andromedans, ten million years from now, should adopt the same phase convention as Earthlings do now. Personally, I find this argument unconvincing. There exist, after all, other symmetries with phases that remain constant over the whole of spacetime. For example, the replacements (see
# https://arxiv.org/pdf/hep-ph/0410370.pdf, p. 9)
#
# \begin{align*}
#     Q & \rightarrow e^{i \theta / 3} Q,\\
#     u_R & \rightarrow e^{i \theta / 3} u_R, \\
#     d_R & \rightarrow e^{i \theta / 3} d_R, \\
#     \textrm{and} & \\
#     L &  \rightarrow e^{i \phi } L, \\
#     e_R & \rightarrow e^{i \phi } e_R,
# \end{align*}
#
# which correspond to baryon number and lepton number conservation, respectively, are __global symmetries__ that leave the Lagrangian invariant. These global symmetries were not imposed, but appear for free and are,
# in that sense, accidental. My question is:
# why is it fine to have global symmetries where certain quantities, such as $\theta$ and $\phi$ *must* be the same everywhere and everywhen, that is, Andromedans and Earthlings must use the same values of these phases even though they have never met, and yet it is not
# fine to have the same gauge field phases everywhere? There is no good reason that I can discern. I think it is better simply to accept the
# discovery that local gauge invariance yields theories, which for reasons not
# yet clear, are spectacularly successful.
#
# ### Hypercharges
# The hypercharge $Y$, electric charge $Q$ (in units of the proton charge and not to be confused with the quark doublet), and the third component of the (weak) isospin $I_3 = \pm 1/2$ are related by the Gell-Mann Nishijima relation $Y = 2(Q - I_3)$.
# For the left-handed neutrino field, $Q = 0$ and $I_3 = +1/2$, therefore, the hypercharge is $Y_L = -1$.
# For the left-handed electron field, $Q = -1$ and $I_3 = -1/2$ and again $Y_L = -1$. On
# the other hand, since the right-handed electron field is an $SU(2)$ singlet and, therefore, transforms trivially, that is, $e_R \rightarrow e_R$, $I_3 = 0$ and therefore $Y_R = -2$. We conclude that the hypercharge is a property of the doublet or singlet.
#
# In the quark model, up quarks have electric charge $Q = +2/3$ (in units of the proton charge), while down quarks have electric charge $Q =  -1/3$.
# Therefore, in order to satisfy the Gell-Mann Nishijima relation we must make the
# assignments $Y^Q_L = 1/3$, $Y^u_R = 4/3$, and $Y^d_R = -2/3$.
#
# ### Bosons
# If we define $X_\mu = (\boldsymbol{\tau}/2) \cdot \mathbf{W}_\mu$ and $X_{\mu\nu} = (\boldsymbol{\tau}/2) \cdot\mathbf{W}_{\mu\nu}$, and noting that $\tau^a \tau^b = i \epsilon_{abc} \tau^c + \delta_{ab}\mathbf{1}$ and,
# therefore, $\textrm{Tr}(\tau^a \tau^b) = 2 \delta_{ab}$, we can write
# \begin{align*}
#     X_{\mu\nu} & = \partial_\mu X_\nu - \partial_\nu X_\mu + i g_2 [X_\mu, X_\nu] ,
# \end{align*}
# and, therefore,
# \begin{align*}
# \mathbf{W}_{\mu\nu} \cdot \mathbf{W}^{\mu\nu} & = \frac{1}{2}\textrm{Tr}(X_{\mu\nu} X^{\mu\nu}) .
# \end{align*}
#
# In the low energy limit ($q^2 << M_W$, where the W boson mass $M_W \sim 80\,$GeV), the GSW model reproduces the Fermi model for $\beta$-decay provided that we set
# $$\frac{G_F}{\sqrt{2}} = \frac{g_2^2}{8 M_W^2}.$$

# %% [markdown]
# Tip: To disable a cell use __esc r__; use __esc y__ to reactivate it and __esc m__ to go to markdown mode.

# %%
# load symbolic algebra module
import sympy as sm
import sympy.functions.special.tensor_functions as t
from sympy.matrices import Matrix
from sympy.physics.matrices import mgamma, msigma
from sympy import I, trigsimp, radsimp

# enable pretty printing of equations
sm.init_printing()

levi = t.LeviCivita
kron = t.KroneckerDelta

# %% [markdown]
# ### Define fields
# Alas, the particle physics literature is littered with differing conventions for defining the fields. In the textbook by Mark Thomson, $W^\pm_\mu = \frac{1}{\sqrt{2}} (W^1_\mu \mp W^2_\mu)$, while in the textbook by Gordon Kane (Modern Elementary Particle Physics, 2nd Edition) these fields are defined by $W^\pm_\mu = \frac{1}{\sqrt{2}} (-W^1_\mu \mp W^2_\mu)$. And in the book by Donnelly, Formaggio, Holstein, Milner, and Surrow (Foundations of Nuclear and Particle Physics), the convention is $W^\pm_\mu = \frac{1}{\sqrt{2}} (W^1_\mu \pm W^2_\mu)$. Here, we'll follow the convention in Thomson's book.

# %%
# make the following symbols non-commutative so that the order in which
# they are written is preserved.
gamma  = sm.Symbol('\gamma^{\mu}', commutative=False)
nubarL = sm.Symbol('\overline{\\nu}_L', commutative=False)
nuL    = sm.Symbol('\\nu_L', commutative=False)
ebarL  = sm.Symbol('\overline{e}_L', commutative=False)
eL     = sm.Symbol('e_L', commutative=False)
ebarR  = sm.Symbol('\overline{e}_R', commutative=False)
eR     = sm.Symbol('e_R', commutative=False)

ubarL  = sm.Symbol('\overline{u}_L', commutative=False)
uL     = sm.Symbol('u_L', commutative=False)
ubarR  = sm.Symbol('\overline{u}_R', commutative=False)
uR     = sm.Symbol('u_R', commutative=False)

dbarL  = sm.Symbol('\overline{d}_L', commutative=False)
dL     = sm.Symbol('d_L', commutative=False)
dbarR  = sm.Symbol('\overline{d}_R', commutative=False)
dR     = sm.Symbol('d_R', commutative=False)

sbarL  = sm.Symbol('\overline{s}_L', commutative=False)
sL     = sm.Symbol('s_L', commutative=False)
sbarR  = sm.Symbol('\overline{s}_R', commutative=False)
sR     = sm.Symbol('s_R', commutative=False)

cbarL  = sm.Symbol('\overline{c}_L', commutative=False)
cL     = sm.Symbol('c_L', commutative=False)
cbarR  = sm.Symbol('\overline{c}_R', commutative=False)
cR     = sm.Symbol('c_R', commutative=False)

# these do not have to be non-commutative
B, W1, W2, W3         = sm.symbols("B_\mu, W^1_\mu, W^2_\mu, W^3_\mu")
Bnu, W1nu, W2nu, W3nu = sm.symbols("B_\\nu, W^1_\\nu, W^2_\\nu, W^3_\\nu")
Wplus, Wminus         = sm.symbols("W^+_\mu, W^-_\mu")
Wplusnu,Wminusnu,W3nu = sm.symbols("W^+_\\nu, W^-_\\nu, W^3_\\nu")

Z, A     = sm.symbols('Z_\mu, A_\mu')
Znu, Anu = sm.symbols('Z_\\nu, A_\\nu')

nuL, eL, eR, uL, uR, dL, dR, B, W1, W2, W3
# Out:
# (\nu_L, e_L, e_R, u_L, u_R, d_L, d_R, B_\mu, W_\mu__1, W_\mu__2, W_\mu__3)

# %%
Wplus, Wminus, Z, A
# Out:
# (W_\mu__+, W_\mu__-, Z_\mu, A_\mu)

# %% [markdown]
# ### Define couplings, hypercharges, and weak mixing angle $\theta_W$

# %%
g1, g2, q, thetaW     = sm.symbols('g_1 g_2 q \\theta_W')
YQL, YdL, YuR, YdR = sm.symbols('Y^Q_L Y^d_L Y^u_R Y^d_R')
YL, YR, YphiL      = sm.symbols('Y_L Y_R Y_L^\phi')
g1, g2, q, YL, YR, YQL, YuR, YdR, YphiL, thetaW
# Out:
# (g₁, g₂, q, Y_L, Y_R, Y_L__Q, Y_R__u, Y_R__d, Y_L__\phi, \theta_W)

# %% [markdown]
# ### Define $SU(2)$ lepton and quark doublets $L$ and $Q$

# %%
L = Matrix([nuL, eL])
Lbar = Matrix([nubarL, ebarL]).T

Q = Matrix([uL, dL])
Qbar = Matrix([ubarL, dbarL]).T

Lbar, L, Qbar, Q
# Out:
# ⎛                                    ⎡\nu_L⎤
# ⎜[\overline{\nu}_L  \overline{e}_L], ⎢     ⎥, [\overline{u}_L  \overline{d}_L]
# ⎝                                    ⎣ e_L ⎦
#
#   ⎡u_L⎤⎞
# , ⎢   ⎥⎟
#   ⎣d_L⎦⎠

# %% [markdown]
# ### Define $\tau \cdot W$ matrix

# %%
tau1 = msigma(1)
tau2 = msigma(2)
tau3 = msigma(3)
w    = tau1*W1 + tau2*W2 + tau3*W3
w
# Out:
# ⎡      W_\mu__3         W_\mu__1 - ⅈ⋅W_\mu__2⎤
# ⎢                                            ⎥
# ⎣W_\mu__1 + ⅈ⋅W_\mu__2        -W_\mu__3      ⎦

# %% [markdown]
# The fields $W^1_\mu \mp i W^2_\mu$ have the form of charged fields, which  we write as $(W^1_\mu \mp i W^2_\mu) \, / \, \sqrt{2} \rightarrow  W^\pm_\mu$, and are identified as the fields of the charged weak bosons.

# %%
w = w.subs({W1 - I*W2: sm.sqrt(2)*Wplus,
            W1 + I*W2: sm.sqrt(2)*Wminus})
w
# Out:
# ⎡ W_\mu__3    √2⋅W_\mu__+⎤
# ⎢                        ⎥
# ⎣√2⋅W_\mu__-   -W_\mu__3 ⎦

# %% [markdown]
# ### Define matrix $b$

# %%
b = B*tau1**2 
b
# Out:
# ⎡B_\mu    0  ⎤
# ⎢            ⎥
# ⎣  0    B_\mu⎦

# %% [markdown]
# ### Compute matrices
# \begin{align}
#     M_L & =  g_1 \frac{Y_L}{2} B_\mu +  g_2 \frac{\boldsymbol{\tau}}{2} \cdot \mathbf{W}_\mu
# \end{align}
#
# and
#
# \begin{align}
#     M_Q & =  g_1 \frac{Y^Q_L}{2} B_\mu +  g_2 \frac{\boldsymbol{\tau}}{2} \cdot \mathbf{W}_\mu
# \end{align}

# %%
ML = (g1/2)*YL*b + (g2/2)*w

MQ = (g1/2)*YQL*b + (g2/2)*w

ML, MQ
# Out:
# ⎛⎡B_\mu⋅Y_L⋅g₁   W_\mu__3⋅g₂        √2⋅W_\mu__+⋅g₂      ⎤  ⎡B_\mu⋅Y_L__Q⋅g₁
# ⎜⎢──────────── + ───────────        ──────────────      ⎥  ⎢─────────────── +
# ⎜⎢     2              2                   2             ⎥  ⎢       2
# ⎜⎢                                                      ⎥, ⎢
# ⎜⎢      √2⋅W_\mu__-⋅g₂        B_\mu⋅Y_L⋅g₁   W_\mu__3⋅g₂⎥  ⎢       √2⋅W_\mu__-
# ⎜⎢      ──────────────        ──────────── - ───────────⎥  ⎢       ───────────
# ⎝⎣            2                    2              2     ⎦  ⎣             2
#
# W_\mu__3⋅g₂         √2⋅W_\mu__+⋅g₂        ⎤⎞
# ───────────         ──────────────        ⎥⎟
#      2                    2               ⎥⎟
#                                           ⎥⎟
# ⋅g₂          B_\mu⋅Y_L__Q⋅g₁   W_\mu__3⋅g₂⎥⎟
# ───          ─────────────── - ───────────⎥⎟
#                     2               2     ⎦⎠

# %% [markdown]
# ### Expand
# $- \bar{L} \gamma^\mu M_L L - \bar{Q} \gamma^\mu M_Q Q$
#
# Note: we had to switch the order of gamma and Lbar for the algebra to look correct.

# %%
l = sm.expand(-gamma*Lbar*ML*L)[0] + sm.expand(-gamma*Qbar*MQ*Q)[0]
l
# Out:
#   B_\mu⋅Y_L__Q⋅g₁⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L   B_\mu⋅Y_L__Q⋅g₁⋅\overline
# - ──────────────────────────────────────────────── - ─────────────────────────
#                          2                                                  2
#
# {u}_L⋅\gamma__{\mu}⋅u_L   B_\mu⋅Y_L⋅g₁⋅\overline{\nu}_L⋅\gamma__{\mu}⋅\nu_L
# ─────────────────────── - ───────────────────────────────────────────────── -
#                                                   2
#
# B_\mu⋅Y_L⋅g₁⋅\overline{e}_L⋅\gamma__{\mu}⋅e_L   √2⋅W_\mu__+⋅g₂⋅\overline{\nu}_
# ───────────────────────────────────────────── - ──────────────────────────────
#                       2                                                 2
#
# L⋅\gamma__{\mu}⋅e_L   √2⋅W_\mu__+⋅g₂⋅\overline{u}_L⋅\gamma__{\mu}⋅d_L   √2⋅W_\
# ─────────────────── - ─────────────────────────────────────────────── - ──────
#                                              2
#
# mu__-⋅g₂⋅\overline{d}_L⋅\gamma__{\mu}⋅u_L   √2⋅W_\mu__-⋅g₂⋅\overline{e}_L⋅\gam
# ...

# %% [markdown]
# ### The singlet terms
# \begin{align*}
# - \frac{g_1}{2} Y_{R} B_{\mu} \bar{e}_R \gamma^\mu  e_R
# - \frac{g_1}{2} Y^u_{R} B_{\mu} \bar{u}_R \gamma^\mu  u_R
# - \frac{g_1}{2} Y^d_{R} B_{\mu} \bar{d}_R \gamma^\mu  d_R
# \end{align*}

# %%
r  = (g1/2)*YR*B*ebarR*gamma*eR 
r += (g1/2)*YuR*ubarR*gamma*B*uR
r += (g1/2)*YdR*dbarR*gamma*B*dR
r  = -r
r
# Out:
#   B_\mu⋅Y_R__d⋅g₁⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R   B_\mu⋅Y_R__u⋅g₁⋅\overline
# - ──────────────────────────────────────────────── - ─────────────────────────
#                          2                                                  2
#
# {u}_R⋅\gamma__{\mu}⋅u_R   B_\mu⋅Y_R⋅g₁⋅\overline{e}_R⋅\gamma__{\mu}⋅e_R
# ─────────────────────── - ─────────────────────────────────────────────
#                                                 2

# %% [markdown]
# ### The unification of the electromagnetic and weak nuclear forces
# The key idea in the GSW model, as in the original 1961 model by Glashow, is that the fields $B_\mu$ and $W_\mu^3$ are related to $A_\mu$ and $Z_\mu$ as follows
#
# \begin{align}
#     \begin{pmatrix} B_\mu \\ W^3_\mu \end{pmatrix} & =
#     \begin{pmatrix}
#         \cos\theta_W & -\sin\theta_W \\
#         \sin\theta_W & \cos\theta_W
#     \end{pmatrix}     \begin{pmatrix} A_\mu \\ Z_\mu \end{pmatrix} .
# \end{align}
#
# The Glashow hypothesis is that the electromagnetic and weak nuclear forces are related and, therefore, unified in the following sense.
# Above a certain critical temperature, the symmetry between the two forces (called the electroweak symmetry) is restored and the two forces merge into a single __electroweak force__. Below the critical temperature, the electroweak symmetry is said to be *spontaneously broken* by the change in shape of the potential energy of the Higgs field, which we discuss below. Because of the changed shape (which, to date, is introduced by hand), the theory yields infinitely many vacuum state solutions. While this infinite *ensemble* of vacuum state solutions collectively respect the electroweak symmetry, the particular vacuum state into which the universe settles does not.
#
# This feature is analogous to that of an infinite ferromagnet. Above a certain critical temperature, called the Curie temperature, the magnetic moments of the ferromagnet's domains are randomly oriented. Therefore, when averaged over the whole ferromagnet there is no net magnetization and the ferromagnet exhibits an $O(3)$ symmetry, that is, it is invariant with respect to rotations in 3-D space. However, well below the Curie temperatue, the magnetic moments line up in the same randomly selected direction, which causes the system to lose its $O(3)$ symmetry. Thus, the ground state of the ferromagnetic with its net magnetization does not share the symmetry of the equations that describe the system. However, collectively, the infinite ensemble of possible ground states still preserves the symmetry in the sense that a simultaneous rotation of all of the ground states in the same way doesn't change the ensemble.
#
# We should be thankful for broken symmetry because without it the universe would be far less diverse and we would not exist.

# %%
AZv = Matrix([A, Z])
rot = Matrix([[sm.cos(thetaW), -sm.sin(thetaW)],
              [sm.sin(thetaW),  sm.cos(thetaW)]])
BW  = rot * AZv
BW
# Out:
# ⎡A_\mu⋅cos(\theta_W) - Z_\mu⋅sin(\theta_W)⎤
# ⎢                                         ⎥
# ⎣A_\mu⋅sin(\theta_W) + Z_\mu⋅cos(\theta_W)⎦

# %% [markdown]
# ### Collect terms for $A_\mu$ and $Z_\mu$ fields
# First substitute the fields $B_\mu$ and $W_\mu^3$ for $A_\mu$ and $Z_\mu$, then collect (that is, group) the coefficients of the latter.

# %%
a = l + r
a = a.subs(B,  BW[0])
a = a.subs(W3, BW[1])
a = a.expand().collect(A).collect(Z).collect(Wplus).collect(Wminus)
a
# Out:
#       ⎛  Y_L__Q⋅g₁⋅cos(\theta_W)⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L   Y_L__Q⋅g₁⋅
# A_\mu⋅⎜- ──────────────────────────────────────────────────────── - ──────────
#       ⎝                             2
#
# cos(\theta_W)⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L   Y_R__d⋅g₁⋅cos(\theta_W)⋅\over
# ────────────────────────────────────────────── - ─────────────────────────────
#                  2                                                          2
#
# line{d}_R⋅\gamma__{\mu}⋅d_R   Y_R__u⋅g₁⋅cos(\theta_W)⋅\overline{u}_R⋅\gamma__{
# ─────────────────────────── - ────────────────────────────────────────────────
#                                                          2
#
# \mu}⋅u_R   Y_L⋅g₁⋅cos(\theta_W)⋅\overline{\nu}_L⋅\gamma__{\mu}⋅\nu_L   Y_L⋅g₁⋅
# ──────── - ───────────────────────────────────────────────────────── - ───────
#                                        2
#
# cos(\theta_W)⋅\overline{e}_L⋅\gamma__{\mu}⋅e_L   Y_R⋅g₁⋅cos(\theta_W)⋅\overlin
# ...

# %% [markdown]
# In the above expression there is an interaction between the electromagnetic field $A_\mu$ and the neutrino current $\bar{\nu}_L \gamma^\mu \nu_L$. However, so far, we have no evidence that such an interaction exists. Therefore, guided by this fact, we need to get rid of that interaction. This can be done if we set  $$-Y_L \, g_1\cos\theta_W = g_2\sin\theta_W.$$

# %%
a = a.subs(-YL*g1*sm.cos(thetaW), g2*sm.sin(thetaW))
a
# Out:
#       ⎛  Y_L__Q⋅g₁⋅cos(\theta_W)⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L   Y_L__Q⋅g₁⋅
# A_\mu⋅⎜- ──────────────────────────────────────────────────────── - ──────────
#       ⎝                             2
#
# cos(\theta_W)⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L   Y_R__d⋅g₁⋅cos(\theta_W)⋅\over
# ────────────────────────────────────────────── - ─────────────────────────────
#                  2                                                          2
#
# line{d}_R⋅\gamma__{\mu}⋅d_R   Y_R__u⋅g₁⋅cos(\theta_W)⋅\overline{u}_R⋅\gamma__{
# ─────────────────────────── - ────────────────────────────────────────────────
#                                                          2
#
# \mu}⋅u_R   Y_R⋅g₁⋅cos(\theta_W)⋅\overline{e}_R⋅\gamma__{\mu}⋅e_R   g₂⋅sin(\the
# ──────── - ───────────────────────────────────────────────────── + ───────────
#                                      2
#
# ta_W)⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L
# ────────────────────────────────────── + g₂⋅sin(\theta_W)⋅\overline{e}_L⋅\gamm
# ...

# %% [markdown]
# So far, so good. Now, if this theory has something to do with reality, we need to recover the known form of the electromagnetic interaction, which for electrons is $q  A_\mu (\bar{e}_L \gamma^\mu e_L + \bar{e}_R \gamma^\mu e_R )$, where $q$ is the electic charge of the associated particle. We can
# do this if we impose the conditions
#
# \begin{align*}
#     -(Y_R / 2) g_1 \cos\theta_W & = g_2 \sin\theta_W = q,
# \end{align*}
#
# or, equivalently,
#
# \begin{align*}
#     \cos\theta_W & = -\frac{q}{g_1 (Y_R/2)} \, \textrm{ and }\\
#     \sin\theta_W & = \frac{q}{g_2}.
# \end{align*}
#
# The above expressions imply
#
# \begin{align*}
#     q & = \frac{g_1 g_2 (Y_R/2)}{\sqrt{g_1^2 (Y_R/2)^2 + g_2^2}}, \\
#     \tan\theta_W & = -(Y_R/2)\frac{g_1}{g_2}
# \end{align*}

# %%
a = a.subs({-YR*g1*sm.cos(thetaW): 2*g2*sm.sin(thetaW) })
a
# Out:
#       ⎛  Y_L__Q⋅g₁⋅cos(\theta_W)⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L   Y_L__Q⋅g₁⋅
# A_\mu⋅⎜- ──────────────────────────────────────────────────────── - ──────────
#       ⎝                             2
#
# cos(\theta_W)⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L   Y_R__d⋅g₁⋅cos(\theta_W)⋅\over
# ────────────────────────────────────────────── - ─────────────────────────────
#                  2                                                          2
#
# line{d}_R⋅\gamma__{\mu}⋅d_R   Y_R__u⋅g₁⋅cos(\theta_W)⋅\overline{u}_R⋅\gamma__{
# ─────────────────────────── - ────────────────────────────────────────────────
#                                                          2
#
# \mu}⋅u_R   g₂⋅sin(\theta_W)⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L
# ──────── + ───────────────────────────────────────────────── + g₂⋅sin(\theta_W
#                                    2
#
#
# )⋅\overline{e}_L⋅\gamma__{\mu}⋅e_L + g₂⋅sin(\theta_W)⋅\overline{e}_R⋅\gamma__{
#
#
# ...

# %% [markdown]
# ### Simplify expressions
# We extract the coefficients of the bosonic fields, that is, the currents, and manipulate them into the forms in which they are typically expressed.

# %% [markdown]
# ### Get coefficient of $W^+_\mu$

# %%
Wpluscoeff  = a.coeff(Wplus)
Wpluscoeff  = Wpluscoeff.subs(g2, q/sm.sin(thetaW)).factor(q).simplify()
Wpluscoeff
# Out:
# -√2⋅q⋅(\overline{\nu}_L⋅\gamma__{\mu}⋅e_L + \overline{u}_L⋅\gamma__{\mu}⋅d_L)
# ──────────────────────────────────────────────────────────────────────────────
#                                2⋅sin(\theta_W)

# %% [markdown]
# ### Get coefficient of $W^-_\mu$

# %%
Wminuscoeff = l.coeff(Wminus)
Wminuscoeff = Wminuscoeff.subs(g2, q/sm.sin(thetaW)).factor(q).simplify()
Wminuscoeff
# Out:
# -√2⋅q⋅(\overline{d}_L⋅\gamma__{\mu}⋅u_L + \overline{e}_L⋅\gamma__{\mu}⋅\nu_L)
# ──────────────────────────────────────────────────────────────────────────────
#                                2⋅sin(\theta_W)

# %% [markdown]
# ### Get coefficient of $A_\mu$

# %%
N, E, U, D = sm.symbols('N, E, U, D')

Acoeff = a.coeff(A).expand()

Acoeff = Acoeff.subs({ebarL*gamma*eL: E,
                      ubarL*gamma*uL: U, 
                      dbarL*gamma*dL: D})
Acoeff = Acoeff.collect(E).collect(U).collect(D)

Acoeff = Acoeff.subs({E:ebarL*gamma*eL, 
                      U: ubarL*gamma*uL, 
                      D: dbarL*gamma*dL})

Acoeff = Acoeff.subs(g1, g2*sm.sin(thetaW)/sm.cos(thetaW))

Acoeff = Acoeff.subs({g2*sm.sin(thetaW): q})

Acoeff
# Out:
#   Y_R__d⋅q⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R   Y_R__u⋅q⋅\overline{u}_R⋅\gamma__
# - ───────────────────────────────────────── - ────────────────────────────────
#                       2                                           2
#
# {\mu}⋅u_R
# ───────── + q⋅\overline{e}_L⋅\gamma__{\mu}⋅e_L + q⋅\overline{e}_R⋅\gamma__{\mu
#
#
#         ⎛  Y_L__Q⋅q   q⎞                                    ⎛  Y_L__Q⋅q   q⎞
# }⋅e_R + ⎜- ──────── - ─⎟⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L + ⎜- ──────── + ─⎟⋅\
#         ⎝     2       2⎠                                    ⎝     2       2⎠
#
#
# overline{d}_L⋅\gamma__{\mu}⋅d_L

# %% [markdown]
# ### Hypercharge assignments
# One of the key manipulations is substituting the appropriate expressions for the hypercharges. We assume the validity of the relation $Y = 2(Q - I_3)$, where $Q$ and $I_3$, respectively, are the electric charge in units of the proton charge and the 3rd component of the isospin. Recall that $Y_L = -1$ for the lepton doublet $L$. We also showed above that $Y_R = -2$ for the lepton singlets. Similarly, $Y^Q_L = 2 (Q^f - I^f_3) = 1/3$, $Y^u_R = 2 Q^u = 4/3$, where $f$ is the fermion flavor, and $Y^d_R = 2 Q^d = -2/3$.

# %%
Qf, Qu, Qd, Qe, Qnu = sm.symbols('Q^f, Q^u, Q^d, Q^e, Q^\\nu')
If3, Id3, Iu3, Ie3, Inu3 = sm.symbols('I^f_3, I^d_3, I^u_3, I^e_3, I^\\nu_3')
q, Qf, Qu, Qd, Qe, Qnu, If3, Id3, Iu3, Ie3, Inu3
# Out:
# (q, Q__f, Q__u, Q__d, Q__e, Q__\nu, I_3__f, I_3__d, I_3__u, I_3__e, I_3__\nu)

# %% [markdown]
# Implement hypercharge assignments for electromagnetic current.

# %%
Acoeff = Acoeff.subs(YuR, 2*Qu)
Acoeff = Acoeff.subs(YdR, 2*Qd)
Acoeff = Acoeff.subs(YQL, 2*(Qf - If3))
Acoeff
# Out:
#
# -Q__d⋅q⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R - Q__u⋅q⋅\overline{u}_R⋅\gamma__{\mu}
#
#
#
# ⋅u_R + q⋅\overline{e}_L⋅\gamma__{\mu}⋅e_L + q⋅\overline{e}_R⋅\gamma__{\mu}⋅e_R
#
#
#    ⎛  q⋅(-2⋅I_3__f + 2⋅Q__f)   q⎞                                    ⎛  q⋅(-2⋅
#  + ⎜- ────────────────────── - ─⎟⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L + ⎜- ──────
#    ⎝            2              2⎠                                    ⎝
#
# I_3__f + 2⋅Q__f)   q⎞
# ──────────────── + ─⎟⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L
#     2              2⎠

# %%
# up quark current
old = Acoeff.coeff(ubarL*gamma*uL)
new = old.subs({2*If3: 1, Qf: Qu})
Acoeff = Acoeff.subs({old: new})

# down quark current
old = Acoeff.coeff(dbarL*gamma*dL)
new = old.subs({2*If3:-1, Qf: Qd})
Acoeff = Acoeff.subs({old: new}).simplify()

Acoeff
# Out:
# q⋅(-Q__d⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L - Q__d⋅\overline{d}_R⋅\gamma__{\mu}⋅
# d_R - Q__u⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L - Q__u⋅\overline{u}_R⋅\gamma__{\mu
# }⋅u_R + \overline{e}_L⋅\gamma__{\mu}⋅e_L + \overline{e}_R⋅\gamma__{\mu}⋅e_R)

# %% [markdown]
# From the above we see that the electromagnetic current $J^\mu_\textrm{em}$ can be written as
# \begin{align*}
# J^\mu_\textrm{em} & = - q \sum_{f = u, d, e} Q^f \overline{\psi}^f \gamma^\mu \psi^f,
# \end{align*}
# where $\psi = \psi_L + \psi_R$, noting that $P_{L,R} \gamma^\mu P_{L, R} = 0$, where $Q^f$ is the electic charge in units of the proton charge for the quantum field of flavor $f$.

# %% [markdown]
# ### Get coefficient of $Z_\mu$
# Do some algebraic manipulations to simplify expression.
# Unfortunately, collect does not work with non-commutative symbols. So try the following hack.

# %%
Zcoeff = a.coeff(Z)

Zcoeff = Zcoeff.subs({nubarL*gamma*nuL: N, 
                      ebarL*gamma*eL: E,
                      ubarL*gamma*uL: U, 
                      dbarL*gamma*dL: D})
Zcoeff = Zcoeff.collect(E).collect(N).collect(U).collect(D)

Zcoeff = Zcoeff.subs({N:nubarL*gamma*nuL, 
                      E:ebarL*gamma*eL, 
                      U: ubarL*gamma*uL, 
                      D: dbarL*gamma*dL})
Zcoeff = Zcoeff.subs(g1, g2*sm.sin(thetaW)/sm.cos(thetaW))

Zcoeff
# Out:
#              2                                                           2
# Y_R__d⋅g₂⋅sin (\theta_W)⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R   Y_R__u⋅g₂⋅sin (\th
# ───────────────────────────────────────────────────────── + ──────────────────
#                      2⋅cos(\theta_W)
#
#                                                     2
# eta_W)⋅\overline{u}_R⋅\gamma__{\mu}⋅u_R   Y_R⋅g₂⋅sin (\theta_W)⋅\overline{e}_R
# ─────────────────────────────────────── + ────────────────────────────────────
#    2⋅cos(\theta_W)                                           2⋅cos(\theta_W)
#
#                      ⎛             2                             ⎞
# ⋅\gamma__{\mu}⋅e_R   ⎜Y_L__Q⋅g₂⋅sin (\theta_W)   g₂⋅cos(\theta_W)⎟
# ────────────────── + ⎜──────────────────────── - ────────────────⎟⋅\overline{u
#                      ⎝    2⋅cos(\theta_W)               2        ⎠
#
#                         ⎛             2                             ⎞
# ...

# %% [markdown]
# Notice that the coefficients of $g_2 \cos(\theta_W)$ is equal to $-I_3$. Therefore, let's make those substitutions in the above.

# %%
old = Zcoeff.coeff(ubarL*gamma*uL)
new = old.subs({g2*sm.cos(thetaW)/2: g2*Iu3*sm.cos(thetaW)}).factor(g2)
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(dbarL*gamma*dL)
new = old.subs({g2*sm.cos(thetaW)/2: -g2*Id3*sm.cos(thetaW)}).factor(g2)
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(nubarL*gamma*nuL)
new = old.subs({g2*sm.cos(thetaW)/2: g2*Inu3*sm.cos(thetaW)}).factor(g2)
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(ebarL*gamma*eL)
new = old.subs({g2*sm.cos(thetaW)/2: -g2*Ie3*sm.cos(thetaW)}).factor(g2)
Zcoeff = Zcoeff.subs({old: new})

Zcoeff
# Out:
#              2                                                           2
# Y_R__d⋅g₂⋅sin (\theta_W)⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R   Y_R__u⋅g₂⋅sin (\th
# ───────────────────────────────────────────────────────── + ──────────────────
#                      2⋅cos(\theta_W)
#
#                                                     2
# eta_W)⋅\overline{u}_R⋅\gamma__{\mu}⋅u_R   Y_R⋅g₂⋅sin (\theta_W)⋅\overline{e}_R
# ─────────────────────────────────────── + ────────────────────────────────────
#    2⋅cos(\theta_W)                                           2⋅cos(\theta_W)
#
#                         ⎛                2                    2          ⎞
# ⋅\gamma__{\mu}⋅e_R   g₂⋅⎝- 2⋅I_3__\nu⋅cos (\theta_W) + Y_L⋅sin (\theta_W)⎠⋅\ov
# ────────────────── + ─────────────────────────────────────────────────────────
#                                                           2⋅cos(\theta_W)
#
#                                        ⎛              2
# ...

# %% [markdown]
# Implement hypercharge assignments for weak neutral current. Note the $I_3$ value for singlet fields is always zero.

# %%
old = Zcoeff.coeff(dbarR*gamma*dR)
new = old.subs({YdR: 2*Qd}).cancel().factor(g2)
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(ubarR*gamma*uR)
new = old.subs({YuR: 2*Qu}).cancel().factor(g2)
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(ebarR*gamma*eR)
new = old.subs({YR: 2*Qe}).cancel().factor(g2)
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(nubarL*gamma*nuL)
new = old.subs({YL: 2*(Qnu - Inu3)}).simplify()
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(dbarL*gamma*dL)
new = old.subs({YQL: 2*(Qd - Id3)}).simplify()
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(ebarL*gamma*eL)
new = old.subs({YL: 2*(Qe - Ie3)}).simplify()
Zcoeff = Zcoeff.subs({old: new})

old = Zcoeff.coeff(ubarL*gamma*uL)
new = old.subs({YQL: 2*(Qu - Iu3)}).simplify()
Zcoeff = Zcoeff.subs({old: new})

Zcoeff
# Out:
#            2                                                         2
# Q__d⋅g₂⋅sin (\theta_W)⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R   Q__e⋅g₂⋅sin (\theta_
# ─────────────────────────────────────────────────────── + ────────────────────
#                      cos(\theta_W)
#
#                                                  2
# W)⋅\overline{e}_R⋅\gamma__{\mu}⋅e_R   Q__u⋅g₂⋅sin (\theta_W)⋅\overline{u}_R⋅\g
# ─────────────────────────────────── + ────────────────────────────────────────
#  cos(\theta_W)                                             cos(\theta_W)
#
#                      ⎛                     2          ⎞
# amma__{\mu}⋅u_R   g₂⋅⎝I_3__\nu - Q__\nu⋅sin (\theta_W)⎠⋅\overline{\nu}_L⋅\gamm
# ─────────────── - ────────────────────────────────────────────────────────────
#                                                 cos(\theta_W)
#
#                     ⎛                 2          ⎞
# a__{\mu}⋅\nu_L   g₂⋅⎝I_3__d - Q__d⋅sin (\theta_W)⎠⋅\overline{d}_L⋅\gamma__{\mu
# ...

# %%
Zcoeff = Zcoeff.factor(g2).subs({g2: q / sm.sin(thetaW)})
Zcoeff
# Out:
#   ⎛        2                                                      2
# q⋅⎝Q__d⋅sin (\theta_W)⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R + Q__e⋅sin (\theta_W)⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                            2
# \overline{e}_R⋅\gamma__{\mu}⋅e_R + Q__u⋅sin (\theta_W)⋅\overline{u}_R⋅\gamma__
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             ⎛                      2          ⎞
# {\mu}⋅u_R + ⎝-I_3__\nu + Q__\nu⋅sin (\theta_W)⎠⋅\overline{\nu}_L⋅\gamma__{\mu}
# ──────────────────────────────────────────────────────────────────────────────
#                                                    sin(\theta_W)⋅cos(\theta_W)
#
#          ⎛                  2          ⎞                                    ⎛
# ⋅\nu_L + ⎝-I_3__d + Q__d⋅sin (\theta_W)⎠⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L + ⎝-
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ...

# %% [markdown]
# The weak neutral current $J^\mu_\textrm{nc}$ can be written as
# \begin{align*}
# J^\mu_\textrm{nc} & = \frac{2q}{\sin(2\theta_W)} \left(
# \sum_{f = d, e, u} Q^f \sin^2\theta_W \overline{\psi}^f_R \gamma^\mu \psi^f_R +
# \sum_{f = d, e, u, \nu} (-I^f_3 + Q^f \sin^2\theta_W) \, \overline{\psi}^f_L \gamma^\mu \psi^f_L   \right).
# \end{align*}

# %% [markdown]
# ### Final form of  GSW lagrangian for 1st generation fermions

# %% [markdown]
# #### Electromagnetic interactions

# %%
Acoeff*A
# Out:
# A_\mu⋅q⋅(-Q__d⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L - Q__d⋅\overline{d}_R⋅\gamma__
# {\mu}⋅d_R - Q__u⋅\overline{u}_L⋅\gamma__{\mu}⋅u_L - Q__u⋅\overline{u}_R⋅\gamma
# __{\mu}⋅u_R + \overline{e}_L⋅\gamma__{\mu}⋅e_L + \overline{e}_R⋅\gamma__{\mu}⋅
# e_R)

# %% [markdown]
# #### Weak charged current interactions

# %%
Wpluscoeff*Wplus + Wminuscoeff*Wminus
# Out:
#   √2⋅W_\mu__+⋅q⋅(\overline{\nu}_L⋅\gamma__{\mu}⋅e_L + \overline{u}_L⋅\gamma__{
# - ────────────────────────────────────────────────────────────────────────────
#                                      2⋅sin(\theta_W)
#
# \mu}⋅d_L)   √2⋅W_\mu__-⋅q⋅(\overline{d}_L⋅\gamma__{\mu}⋅u_L + \overline{e}_L⋅\
# ───────── - ──────────────────────────────────────────────────────────────────
#                                                2⋅sin(\theta_W)
#
# gamma__{\mu}⋅\nu_L)
# ───────────────────

# %% [markdown]
# #### Weak neutral current interactions

# %%
Zcoeff*Z
# Out:
#         ⎛        2                                                      2
# Z_\mu⋅q⋅⎝Q__d⋅sin (\theta_W)⋅\overline{d}_R⋅\gamma__{\mu}⋅d_R + Q__e⋅sin (\the
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                  2
# ta_W)⋅\overline{e}_R⋅\gamma__{\mu}⋅e_R + Q__u⋅sin (\theta_W)⋅\overline{u}_R⋅\g
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                   ⎛                      2          ⎞
# amma__{\mu}⋅u_R + ⎝-I_3__\nu + Q__\nu⋅sin (\theta_W)⎠⋅\overline{\nu}_L⋅\gamma_
# ──────────────────────────────────────────────────────────────────────────────
#                                                       sin(\theta_W)⋅cos(\theta
#
#                ⎛                  2          ⎞
# _{\mu}⋅\nu_L + ⎝-I_3__d + Q__d⋅sin (\theta_W)⎠⋅\overline{d}_L⋅\gamma__{\mu}⋅d_
# ──────────────────────────────────────────────────────────────────────────────
# _W)
#
# ...

# %% [markdown]
# The GSW model incorporates quantum electrodynamics (QED), predicts weak charged and neutral current interactions and incorporates the observation that neither the electromagnetic nor the weak neutral currrent interactions change flavor, while the weak charged current interactions always do. And, of course, the model incorporates the parity violation of the weak interactions.

# %% [markdown]
# ## The Higgs Sector
# The Higgs Lagrangian is given by
# \begin{align}
#     {\cal L}_\textrm{Higgs} &= (D^\mu \phi)^\dagger (D_\mu \phi) - V(\phi^\dagger \phi) ,
# \end{align}
# where
# \begin{align}
#     D_\mu &= \partial_\mu +
#     i g_1 \frac{Y^\phi_L}{2} B_\mu + i g_2 \frac{\boldsymbol\tau}{2} \cdot \mathbf{W}_\mu,\\
#     V(\phi^\dagger \phi) &= \mu^2 \phi^\dagger \phi + \lambda (\phi^\dagger \phi)^2, \quad\textrm{and the 4-component Higgs field is given by}\\
#     \phi & = \begin{pmatrix}
#     \phi_1 + i \phi_2 \\
#     \phi_3 + i \phi_4
#     \end{pmatrix} .
# \end{align}
#
# #### Qualitative description of the Higgs mechanism
# The stability of the vacuum requires $\lambda > 0$. In the very early universe, we presume that $\mu^2 > 0$, in which case $\langle 0| \phi | 0 \rangle = 0$, that is, the expectation (i.e., average) value of the Higgs field in the vacuum is zero. But, at some critical temperature, $T_\textrm{crit}$, there is a phase transition in which it is presumed that $\mu^2$ changes sign thereby causing the Higgs potential to develop infinitely many degenerate vacua in each of which the Higgs field is non-zero. Above $T_\textrm{crit}$, there is a unique vacuum state and this state respects the symmetry of the Lagrangian. Below $T_\textrm{crit}$, the *ensemble* of vacua respects the symmetry, but, the universe cools into one of the infinitely many potential vacua, which on its own breaks the symmetry. This is an example of *spontaneous symmetry breaking*, which we touched upon above. The specific instance is called electroweak symmetry breaking (EWSB).
#
# The vacuum state of the universe is one in which the Higgs field behaves like a superconductor that attenuates the propagation of the $W_\mu$ and $Z_\mu$ fields, thereby rendering these fields massive, but permits the free propagation of the $A_\mu$ field. (The theory is, of course, made to do this!) Moreover, the interactions between the Higgs field and the fermions, which also are put in by hand, cause a rapid flipping between the left-handed and right-handed fermion fields, which causes energy to build up within them that we interpret as the mass of the associated field quanta, that is, particles.
# The results from the LHC experiment are, so far, consistent with this picture.
#
# Since there is no right-handed neutrino the flipping mechanism cannot occur and therefore
# the neutrino remains massless in the GSW model. However, neutrinos are now known to have (very small) masses,  but, how their masses arise remains an open question.
#
# #### Quantum numbers
# We need to specify the value of the hypercharge $Y^\phi_L$ associated with the doublet $\phi$. As above,  the hypercharge is chosen so that the Gell-Mann Nishijima relation $Y = 2(Q - I_3)$ holds, where the third component of the weak isospin $I_3 = +1/2$ for the upper component of a doublet and $I_3 = -1/2$ for the lower component. In the GSW model, it is assumed that the vacuum expectation of $\phi$ is
# $$\langle 0|\phi|0 \rangle = \frac{1}{\sqrt{2}}\begin{pmatrix} 0 \\ v \end{pmatrix}.$$ Since the vacuum has a net electric charge of zero, we must set $Q = 0$ for the lower component $\phi_3 + i \phi_4$. From $Y^\phi_L = 2 (Q - I_3)$ it follows that $Y^\phi_L = +1$. This also shows that the upper component, $\phi_1 + i \phi_2$ must be assigned $Q = +1$, which of course is why it is assumed to be zero in the vacuum otherwise the entire universe would have a huge net positive electric charge!
#
# #### Higgs field at low energies
# At energies not too far from the vacuum state, we assume that the Higgs field can be approximated as follows
# $$\phi \approx H = \frac{1}{\sqrt{2}}\begin{pmatrix} 0 \\ v + h\end{pmatrix},$$
# where $h$ represents the fluctuations of the Higgs field about its
# average value $v \approx 246 \,\textrm{GeV}$ in the vacuum state (the vacuum expectation value). The quanta of the field $h$ are identified with the Higgs boson discovered at CERN in 2012. There may be zero significance to the numerical fact that $v / \sqrt{2} \approx m_t$, where $m_t$ is the mass of the top quark; or it could be deeply significant. Whatever conclusion is to be drawn, the value of $v$ implies (as we shall see below) that the coupling of the top quark to the Higgs boson is close to (and may even be) unity.
#
# In the following, we shall also need the conjugate field defined by
#
# $$H_c \equiv i \tau_2 H = \frac{1}{\sqrt{2}}\begin{pmatrix} v + h \\ 0 \end{pmatrix}.$$

# %% [markdown]
# ### Compute
# \begin{align}
#     F &= (g_1 / 2) Y^\phi_L B_\mu +  (g_2 / 2) \boldsymbol\tau \cdot \mathbf{W}_\mu
# \end{align}

# %%
v = sm.symbols('v')
h = sm.symbols('h')
H = Matrix([0, (v+h)/sm.sqrt(2)])
F = (g1/2)*YphiL*b + (g2/2)*w
Hc=  sm.I*tau2*H
F, H, Hc
# Out:
# ⎛⎡B_\mu⋅Y_L__\phi⋅g₁   W_\mu__3⋅g₂           √2⋅W_\mu__+⋅g₂         ⎤
# ⎜⎢────────────────── + ───────────           ──────────────         ⎥  ⎡    0
# ⎜⎢        2                 2                      2                ⎥  ⎢
# ⎜⎢                                                                  ⎥, ⎢√2⋅(h
# ⎜⎢         √2⋅W_\mu__-⋅g₂           B_\mu⋅Y_L__\phi⋅g₁   W_\mu__3⋅g₂⎥  ⎢──────
# ⎜⎢         ──────────────           ────────────────── - ───────────⎥  ⎣    2
# ⎝⎣               2                          2                 2     ⎦
#
#                    ⎞
#     ⎤  ⎡√2⋅(h + v)⎤⎟
#     ⎥  ⎢──────────⎥⎟
# + v)⎥, ⎢    2     ⎥⎟
# ────⎥  ⎢          ⎥⎟
#     ⎦  ⎣    0     ⎦⎟
#                    ⎠

# %% [markdown]
# ### Note
# The matrix $F$ is Hermitian, that is, $F^\dagger = F$.
#
# #### Compute
# \begin{align}
#     y & = F H, \\
#     \overline{y} & = H^T F^\dagger,\\
#             & = H^T F .
# \end{align}
#
# Compute
#
# $$f = \overline{y} y.$$

# %%
y    = F*H
ybar = H.T*F
f = ybar*y
f = f[0]
f = f.subs(YphiL, 1)
f = f.subs(g1*B/2 - g2*W3/2, Z * sm.sqrt(g1**2 + g2**2)/2)
f
# Out:
#                     2        2        2 ⎛  2     2⎞        2
# W_\mu__+⋅W_\mu__-⋅g₂ ⋅(h + v)    Z_\mu ⋅⎝g₁  + g₂ ⎠⋅(h + v)
# ────────────────────────────── + ───────────────────────────
#               4                               8

# %% [markdown]
# ### Vector boson - Higgs boson interactions

# %%
f = f.expand()
f = f.collect(Z**2*h).collect(Z**2*v**2)
f
# Out:
#                     2  2                       2                           2
# W_\mu__+⋅W_\mu__-⋅g₂ ⋅h    W_\mu__+⋅W_\mu__-⋅g₂ ⋅h⋅v   W_\mu__+⋅W_\mu__-⋅g₂ ⋅v
# ──────────────────────── + ───────────────────────── + ───────────────────────
#            4                           2                          4
#
# 2             ⎛  2     2⎞            ⎛  2       2  ⎞             ⎛  2     2⎞
#          2  2 ⎜g₁    g₂ ⎟        2   ⎜g₁ ⋅v   g₂ ⋅v⎟        2  2 ⎜g₁    g₂ ⎟
# ─ + Z_\mu ⋅h ⋅⎜─── + ───⎟ + Z_\mu ⋅h⋅⎜───── + ─────⎟ + Z_\mu ⋅v ⋅⎜─── + ───⎟
#               ⎝ 8     8 ⎠            ⎝  4       4  ⎠             ⎝ 8     8 ⎠

# %% [markdown]
# The terms involving the Higgs boson field $h$ in the low-energy limit are the single and di-Higgs boson interactions, while the terms $\propto v^2$ are the mass terms. For a massive vector boson field, $V_\mu$, the mass term has the form $(m_V^2 \, / \, 2) V_\mu V^\mu$. The term $W^+_\mu W^{- \mu}$ is the sum of two terms quadratic in the fields $W^1$ and $W^2$, with the same mass, so the mass term has the form $m_W^2 \, W^+_\mu W^{- \mu}$. Therefore, in the GSW model the $W$ boson mass is predicted to be $m_W = v g_2 \, / \, 2$, while for the $Z$ boson the prediction is $m_Z = v \sqrt{g_1^2+g_2^2} \, / \, 2$ and, therefore, $m_W / m_Z = g_2 / \sqrt{g_1^2 + g_2^2} = \cos\theta_W$, which modulo higher order corrections is in spectacular agreement with measurements as shown below.

# %%
sw2 = 0.2397             # sin^2(theta_W)
sw  = sm.sqrt(sw2)
cw  = sm.sqrt(1-sw2)
print('cos(theta_W) = %8.3f' % cw)
# Out:
# cos(theta_W) =    0.872

# %%
MW  = 80.385 # GeV
MZ  = 91.188 # GeV
cwp = MW/MZ
print('M_W / M_Z    = %8.3f\t%8.3f' % (cwp, cw / cwp))
# Out:
# M_W / M_Z    =    0.882	   0.989

# %% [markdown]
# ### The Higgs potential and Higgs boson self-interactions
#
# $V(H) = \mu^2 H^\dagger H - \lambda (H^\dagger H)^2$

# %%
mu, lm = sm.symbols('\mu, \lambda')
V = mu*mu*H.T*H - lm*(H.T*H)**2
V = V.expand()[0]
V
# Out:
#            4                             2  2                           4
#   \lambda⋅h             3     3⋅\lambda⋅h ⋅v               3   \lambda⋅v    \m
# - ────────── - \lambda⋅h ⋅v - ─────────────── - \lambda⋅h⋅v  - ────────── + ──
#       4                              2                             4
#
#  2  2                 2  2
# u ⋅h       2       \mu ⋅v
# ───── + \mu ⋅h⋅v + ───────
#  2                    2

# %% [markdown]
# ### $h$-$h$ interactions at low energies

# %%
V.subs(mu**2, v**2*lm)
# Out:
#            4                                           4
#   \lambda⋅h             3              2  2   \lambda⋅v
# - ────────── - \lambda⋅h ⋅v - \lambda⋅h ⋅v  + ──────────
#       4                                           4

# %% [markdown]
# The GSW model predicts the existence of tri and quartic Higgs boson self-interactions and a Higgs boson mass given by $m_H = v\sqrt{2}\sqrt{\lambda}$, which using the intriguing ansatz $m_t = v\sqrt{2}$ implies $m_H / m_t = \lambda$.

# %% [markdown]
# ### Yukawa interactions between fermions and the Higgs field
#
# The interactions between the fermions and the Higgs field are presumed to be Yukawa interactions of the form
#
# \begin{align*}
# -\sqrt{2} g_e (\overline{L} H e_R + \overline{e}_R H^\dagger L)
# -\sqrt{2} g_u (\overline{Q} H_c u_R + \overline{u}_R H_c^\dagger Q)
# -\sqrt{2} g_d (\overline{Q} H d_R + \overline{d}_R H^\dagger Q)
# \end{align*}
#
# Let us pause for a minute to consider the dimensions of the above interactions. In natural units, the Lagrangian, which recall is really a Lagrangian density, has units of $[M]^4$ since the measure over spacetime is $d^4x$, which has dimensions of $[M]^{-4}$. Since a fermion mass term looks like
#
# $$m \overline{\psi} \psi$$
#
# and $\textrm{dim}(m) = [M]$, it follows that a fermion field has dimensions $[M]^{3/2}$. Since the Higgs boson is a scalar field, it has dimensions $[M]$. Consequently, the Yukawa interactions between fermions and the Higgs boson must be a gauge invariant combination of two fermion fields with a combined dimension of $[M]^3$ and the Higgs field. Also, because the Higgs field is a doublet, it is necessary to have it interact with the Dirac conjugate of a doublet field and a singlet field.
#
# Notice also that in order to avoid a flavor changing Yukawa interaction, we need to fudge the interaction of the up quark field with the Higgs field by using the conjugate field $H_c$ rather than $H$! By any measure, the GSW model is an amazing intellectual achievement; but it is clear there is still considerable room for improvement.

# %%
ge, me = sm.symbols('g_e, m_e')
gu, mu, gd, md = sm.symbols('g_u, m_u, g_d, m_d')
gu, mu, gd, md
ge, me, gu, mu, gd, md
# Out:
# (gₑ, mₑ, gᵤ, mᵤ, g_d, m_d)

# %%
Hc = sm.I*tau2*H
Qbar, Q, Hc, Hc.T
# Out:
# ⎛                                         ⎡√2⋅(h + v)⎤                 ⎞
# ⎜                                  ⎡u_L⎤  ⎢──────────⎥  ⎡√2⋅(h + v)   ⎤⎟
# ⎜[\overline{u}_L  \overline{d}_L], ⎢   ⎥, ⎢    2     ⎥, ⎢──────────  0⎥⎟
# ⎜                                  ⎣d_L⎦  ⎢          ⎥  ⎣    2        ⎦⎟
# ⎝                                         ⎣    0     ⎦                 ⎠

# %%
Le = -ge*(Lbar*H*eR + ebarR*H.T*L)[0]*sm.sqrt(2)
Le = Le.expand()
Le = Le.simplify().expand().collect(h*ge).collect(ge*v)
Le = Le.subs(ge*v, me)
Le = Le.subs(ge, me/v)
Le
# Out:
# h⋅mₑ⋅(-\overline{e}_R⋅e_L - e_R⋅\overline{e}_L)
# ─────────────────────────────────────────────── + mₑ⋅(-\overline{e}_R⋅e_L - e_
#                        v
#
#
# R⋅\overline{e}_L)

# %%
Lq = -gd*(Qbar*H*dR  + dbarR*H.T*Q)[0]*sm.sqrt(2) \
     -gu*(Qbar*Hc*uR + ubarR*Hc.T*Q)[0]*sm.sqrt(2)
Lq = Lq.expand()
Lq = Lq.subs(gu*v, mu)
Lq = Lq.subs(gd*v, md)
Lq = Lq.collect(gd*h)
Lq = Lq.collect(gu*h)
Lq = Lq.collect(md)
Lq = Lq.collect(mu)
Lq = Lq.subs(gu, mu/v)
Lq = Lq.subs(gd, md/v)
Lq
# Out:
# h⋅m_d⋅(-\overline{d}_R⋅d_L - d_R⋅\overline{d}_L)   h⋅mᵤ⋅(-\overline{u}_R⋅u_L -
# ──────────────────────────────────────────────── + ───────────────────────────
#                        v                                                  v
#
#  u_R⋅\overline{u}_L)
# ──────────────────── + m_d⋅(-\overline{d}_R⋅d_L - d_R⋅\overline{d}_L) + mᵤ⋅(-\
#
#
#
# overline{u}_R⋅u_L - u_R⋅\overline{u}_L)

# %% [markdown]
# We see that the Yukawa couplings, together with the particular choice of the value of the Higgs field in the vacuum state, yields two important consequences as alluded to above: the first is mass terms for the fermions and the second is interactions between the Higgs boson and fermions that are proportional to the fermion mass and inversely proportional to the vacuum expectation value $v$. This implies that the top quark coupling to the Higgs boson is close to, and may be, unity. Why that is, is yet another mystery in a long list of them.
#
# We conclude that the Higgs mechanism generates mass terms for the weak vector bosons as well as the fermions while preserving gauge invariance.

# %% [markdown]
# ### The Cabibbo Hypothesis
# So far we have considered only the 1st generation of particles, of which we have discovered three so far, and we have implicitly assumed that there is no "crosstalk" between the generations. However, there are decays that  can be explained if "crosstalk" exists between generations. For example, the existence of decays such as $$\Lambda (d, u, s) \rightarrow p (d, u, u) \, \, e^- \, \, \bar{\nu}_e$$ are readily explained by supposing that the $W$ boson can convert an s-quark to a u-quark, that is, a 2nd generation quark to a 1st generation quark. Further clues are provided by the rates of decays such as
# \begin{align}
#     \pi^+ & \rightarrow \mu^+ \, \nu_\mu,\\
#     K^+ & \rightarrow \mu^+ \, \nu_\mu,
# \end{align}
# which are measured to be in the ratio
# \begin{align}
#     \frac{\Gamma(\pi^+ \rightarrow \mu^+ \, \nu_\mu)}
#          {\Gamma(K^+ \rightarrow \mu^+ \, \nu_\mu)} & \approx \frac{1}{20}.
# \end{align}
# The above decays can be described with the following Feynman diagrams,
# ![decays](decays01.png)
# in which the couplings $g_2\textrm{?}$ differ from $g_2$ by the appropriate factor in order to match the measured ratio. The pictorial explanation of these decays, just like the decay of positronium (an electron-positron bound system), is that the particles comprising the $\pi^+$ annihilate, in this case to a W boson that subsequently decays leptonically. The observed ratio is readily explained if the W boson can interact with quarks of differing generations, but at a reduced rate compared with that of within generation interactions. These observations and many others were explained by the Italian physicist Cabibbo who suggested that the lower component of the quark doublet, that is, the down quark field, be replaced with the combination
# $$d_L \rightarrow d_L^\prime = \cos\theta_C \, d_L + \sin\theta_C \, s_L,$$
# where $\theta_C$ is called the Cabibbo angle. With a suitable choice of the Cabibbo angle (about 12$^\textrm{o}$), the Cabibbo hypothesis worked well.
# However, as is evident from the form of the down component of the left-handed part of weak neutral current, which is proportional to
# \begin{align}
#  \overline{d}_L \gamma^{\mu} d_{L} ,
# \end{align}
# the Cabibbo hypothesis predicts the existence of flavor-changing neutral currents (FCNC) at a rate in sharp disagreement with observations.

# %%
thetaC = sm.symbols('theta_C')
xbarL, xL = sm.symbols('\overline{d^\prime}_L, '\
                       'd^\prime_L', commutative=False)
Nc = xbarL * gamma * xL 
Nc = Nc.subs({xL: sm.cos(thetaC)*dL + sm.sin(thetaC)*sL,
              xbarL: sm.cos(thetaC)*dbarL + sm.sin(thetaC)*sbarL})
Nc = Nc.expand()
Nc
# Out:
#    2
# sin (θ_C)⋅\overline{s}_L⋅\gamma__{\mu}⋅s_L + sin(θ_C)⋅cos(θ_C)⋅\overline{d}_L⋅
#
#                                                                             2
# \gamma__{\mu}⋅s_L + sin(θ_C)⋅cos(θ_C)⋅\overline{s}_L⋅\gamma__{\mu}⋅d_L + cos (
#
#
# θ_C)⋅\overline{d}_L⋅\gamma__{\mu}⋅d_L

# %% [markdown]
# ### The GIM Mechanism
# In 1970, Sheldon Glashow, John
# Iliopoulos and Luciano
# Maiani (GIM) noted that if the strange quark were the lower component of another doublet, $$\begin{pmatrix} c_L \\ s_L \end{pmatrix},$$
# whose upper component would be a new quark field, dubbed "charm", and if one generalized Cabibbo's idea and assumed that the lower components of the two quark doublets were mixed as follows
# $$\begin{pmatrix} d_L^\prime \\ s_L^\prime \end{pmatrix} =
# \begin{pmatrix} \cos\theta_C & \sin\theta_C \\
# -\sin\theta_C & \cos\theta_C \end{pmatrix} \begin{pmatrix} d_L \\  s_L \end{pmatrix},  $$
# then the replacement
# $$s_L \rightarrow s_L^\prime = -\sin\theta_C \, d_L + \cos\theta_C \, s_L$$
# would yield exact cancellation of the unwanted FCNC interactions at the price of introducing yet another quark field, as demonstrated below.

# %% [markdown]
# ### Implement GIM Mechanism

# %%
ybarL, yL = sm.symbols('\overline{s^\prime}_L, '\
                                  's^\prime_L', 
                                  commutative=False)
# add the GIM terms to the Cabbibo terms
yy = ybarL * gamma * yL
yy = yy.subs({yL:-sm.sin(thetaC)*dL + sm.cos(thetaC)*sL,
              ybarL:-sm.sin(thetaC)*dbarL + sm.cos(thetaC)*sbarL})
yy = yy.expand()
Nc = (Id3 - Qd * sm.sin(thetaW)**2) * Nc
Nc += (Id3 - Qd * sm.sin(thetaW)**2) * yy

# and simplify
Nc = Nc.simplify()
Nc
# Out:
# ⎛                 2          ⎞
# ⎝I_3__d - Q__d⋅sin (\theta_W)⎠⋅(\overline{d}_L⋅\gamma__{\mu}⋅d_L + \overline{s
#
#
# }_L⋅\gamma__{\mu}⋅s_L)

# %% [markdown]
# By introducing a 2nd doublet, the GIM mechanism neatly renders the weak neutral currents diagonal again and predicts the existence of a 4th quark, the charm quark. This prediction was confirmed in stunning fashion in 1974 with the discovery of the $J/\psi$ at Brookhaven and SLAC.
#
# Today, it is known that mixing of the down quark fields occurs across all three generations, which mixing is described by the Cabibbo-Kobayashi-Maskawa (CKM) matrix. Unfortunately, however, no one understands why mixing across the (three) generations should exist, nor why it takes the particular form that it does, and what determines the strength of the mixing.

# %% [markdown]
# ### Vector boson self-interactions
# The pure vector boson Lagrangian is given by
# \begin{align*}
#     {\cal L}_{VB} & = - \frac{1}{4} \mathbf{W}_{\mu\nu} \cdot \mathbf{W}^{\mu\nu} - \frac{1}{4} B_{\mu\nu} B^{\mu\nu},
# \end{align*}
# where
# \begin{align*}
#     \mathbf{W}_{\mu\nu}
#         & = \partial_\mu \mathbf{W}_\nu - \partial_\nu \mathbf{W}_\mu - g_2 \, \mathbf{W}_\mu \times \mathbf{W}_\nu, \\
#     B_{\mu\nu} & = \partial_\mu B_\nu - \partial_\nu B_\mu.
# \end{align*}
#
# From
# \begin{align}
#     \begin{pmatrix} B_\mu \\ W^3_\mu \end{pmatrix} & =
#     \begin{pmatrix}
#         \cos\theta_W & -\sin\theta_W \\
#         \sin\theta_W & \cos\theta_W
#     \end{pmatrix}     \begin{pmatrix} A_\mu \\ Z_\mu \end{pmatrix} \\
#     W^\pm_\mu & = \frac{1}{\sqrt{2}} (W^1_\mu \mp W^2_\mu)
# \end{align}
# we obtain
# \begin{align*}
#     W^1 & = (W^- + W^+)/\sqrt{2}\\
#     W^2 & = (W^- - W^+)/\sqrt(2)\\
#     W^3 & = \sin\theta_W A + \cos\theta_W Z\\
#     B   & = \cos\theta_W A - \sin\theta_W Z,
# \end{align*}
# which we use below to rewrite the vector boson Lagrangian in terms of the usual fields.

# %%
Wplusmu, Wminusmu = sm.symbols("W^+_\mu, W^-_\mu")
Wplusnu, Wminusnu = sm.symbols("W^+_\\nu, W^-_\\nu")

Zmu, Amu          = sm.symbols('Z_\mu, A_\mu')
Znu, Anu          = sm.symbols('Z_\\nu, A_\\nu')

dmuWplusnu        = sm.Symbol('\partial_\mu W^+_\\nu')
dnuWplusmu        = sm.Symbol('\partial_\\nu W^+_\mu')

dmuWminusnu       = sm.Symbol('\partial_\mu W^-_\\nu')
dnuWminusmu       = sm.Symbol('\partial_\\nu W^-_\mu')

dmuZnu            = sm.Symbol('\partial_\mu Z_\\nu')
dnuZmu            = sm.Symbol('\partial_\\nu Z_\mu')

dmuAnu            = sm.Symbol('\partial_\mu A_\\nu')
dnuAmu            = sm.Symbol('\partial_\\nu A_\mu')

W1mu, W2mu, W3mu  = sm.symbols('W^1_\mu W^2_\mu W^3_\mu')
W1nu, W2nu, W3nu  = sm.symbols('W^1_\\nu W^2_\\nu W^3_\\nu')
Bmu, Bnu          = sm.symbols('B_\mu B_\\nu')

dnuW1mu           = sm.Symbol('\partial_\\nu W^1_\mu')
dnuW2mu           = sm.Symbol('\partial_\\nu W^2_\mu')
dnuW3mu           = sm.Symbol('\partial_\\nu W^3_\mu')

dmuW1nu           = sm.Symbol('\partial_\mu W^1_\\nu')
dmuW2nu           = sm.Symbol('\partial_\mu W^2_\\nu')
dmuW3nu           = sm.Symbol('\partial_\mu W^3_\\nu')

dmuBnu            = sm.Symbol('\partial_\mu B_\\nu')
dnuBmu            = sm.Symbol('\partial_\\nu B_\mu')

Vmu = Matrix([W1mu, W2mu, W3mu])
Vnu = Matrix([W1nu, W2nu, W3nu])

dnuVmu = Matrix([dnuW1mu, dnuW2mu, dnuW3mu])
dmuVnu = Matrix([dmuW1nu, dmuW2nu, dmuW3nu])

Vmu, Vnu, Bmu, Bnu, dnuVmu, dmuVnu, dnuBmu, dmuBnu
# Out:
# ⎛⎡W_\mu__1⎤  ⎡W_\nu__1⎤                ⎡\partial_\nu W_\mu__1⎤  ⎡\partial_\mu
# ⎜⎢        ⎥  ⎢        ⎥                ⎢                     ⎥  ⎢
# ⎜⎢W_\mu__2⎥, ⎢W_\nu__2⎥, B_\mu, B_\nu, ⎢\partial_\nu W_\mu__2⎥, ⎢\partial_\mu
# ⎜⎢        ⎥  ⎢        ⎥                ⎢                     ⎥  ⎢
# ⎝⎣W_\mu__3⎦  ⎣W_\nu__3⎦                ⎣\partial_\nu W_\mu__3⎦  ⎣\partial_\mu
#
# W_\nu__1⎤                                        ⎞
#         ⎥                                        ⎟
# W_\nu__2⎥, \partial_\nu B_\mu, \partial_\mu B_\nu⎟
#         ⎥                                        ⎟
# W_\nu__3⎦                                        ⎠

# %%
VmuVnu  = Vmu.cross(Vnu)
VmuVnu
# Out:
# ⎡W_\mu__2⋅W_\nu__3 - W_\nu__2⋅W_\mu__3 ⎤
# ⎢                                      ⎥
# ⎢-W_\mu__1⋅W_\nu__3 + W_\nu__1⋅W_\mu__3⎥
# ⎢                                      ⎥
# ⎣W_\mu__1⋅W_\nu__2 - W_\nu__1⋅W_\mu__2 ⎦

# %%
WW  = dmuVnu - dnuVmu - g2*VmuVnu
BB  = dmuBnu - dnuBmu
WW, BB
# Out:
# ⎛⎡\partial_\mu W_\nu__1 - \partial_\nu W_\mu__1 - g₂⋅(W_\mu__2⋅W_\nu__3 - W_\n
# ⎜⎢
# ⎜⎢\partial_\mu W_\nu__2 - \partial_\nu W_\mu__2 - g₂⋅(-W_\mu__1⋅W_\nu__3 + W_\
# ⎜⎢
# ⎝⎣\partial_\mu W_\nu__3 - \partial_\nu W_\mu__3 - g₂⋅(W_\mu__1⋅W_\nu__2 - W_\n
#
# u__2⋅W_\mu__3) ⎤                                         ⎞
#                ⎥                                         ⎟
# nu__1⋅W_\mu__3)⎥, \partial_\mu B_\nu - \partial_\nu B_\mu⎟
#                ⎥                                         ⎟
# u__1⋅W_\mu__2) ⎦                                         ⎠

# %%
VV = -sm.Rational(1, 4) * (BB*BB +  (WW.T*WW)[0])
VV = VV.expand()
VV
# Out:
#           2         2   2           2         2   2
#   W_\mu__1 ⋅W_\nu__2 ⋅g₂    W_\mu__1 ⋅W_\nu__3 ⋅g₂    W_\mu__1⋅W_\nu__1⋅W_\mu_
# - ─────────────────────── - ─────────────────────── + ────────────────────────
#              4                         4                                 2
#
#               2                                         2
# _2⋅W_\nu__2⋅g₂    W_\mu__1⋅W_\nu__1⋅W_\mu__3⋅W_\nu__3⋅g₂    W_\mu__1⋅W_\nu__2⋅
# ─────────────── + ─────────────────────────────────────── + ──────────────────
#                                      2
#
#
# \partial_\mu W_\nu__3⋅g₂   W_\mu__1⋅W_\nu__2⋅\partial_\nu W_\mu__3⋅g₂   W_\mu_
# ──────────────────────── - ────────────────────────────────────────── - ──────
#   2                                            2
#
#
# _1⋅W_\nu__3⋅\partial_\mu W_\nu__2⋅g₂   W_\mu__1⋅W_\nu__3⋅\partial_\nu W_\mu__2
# ──────────────────────────────────── + ───────────────────────────────────────
# ...

# %% [markdown]
# Now substitute in $Z_\mu$, $A_\mu$, etc.

# %%
VV = VV.subs({W1mu: (Wminusmu + Wplusmu)/sm.sqrt(2), 
              W2mu: (Wminusmu - Wplusmu)/sm.sqrt(2), 
              W3mu: sm.sin(thetaW)*Amu + sm.cos(thetaW)*Zmu, 
              W1nu: (Wminusnu + Wplusnu)/sm.sqrt(2), 
              W2nu: (Wminusnu - Wplusnu)/sm.sqrt(2),  
              W3nu: sm.sin(thetaW)*Anu + sm.cos(thetaW)*Znu, 
              dnuW1mu: (dnuWminusmu + dnuWplusmu)/sm.sqrt(2), 
              dnuW2mu: (dnuWminusmu - dnuWplusmu)/sm.sqrt(2), 
              dnuW3mu: sm.sin(thetaW)*dnuAmu + sm.cos(thetaW)*dnuZmu, 
              dmuW1nu: (dmuWminusnu + dmuWplusnu)/sm.sqrt(2), 
              dmuW3nu: sm.sin(thetaW)*dmuAnu + sm.cos(thetaW)*dmuZnu, 
              dmuBnu:  sm.cos(thetaW)*dmuAnu - sm.sin(thetaW)*dmuZnu, 
              dnuBmu:  sm.cos(thetaW)*dnuAmu - sm.sin(thetaW)*dnuZmu})
VV = VV.expand()
VV = trigsimp(VV.subs({g2: q / sm.sin(thetaW)}))
VV
# Out:
#        2         2  2        2         2  2                                  2
#   A_\mu ⋅W_\nu__+ ⋅q    A_\mu ⋅W_\nu__- ⋅q    A_\mu⋅A_\nu⋅W_\mu__+⋅W_\nu__+⋅q
# - ─────────────────── - ─────────────────── + ────────────────────────────────
#            4                     4                           2
#
#
#                                   2                                  2
#    A_\mu⋅A_\nu⋅W_\mu__-⋅W_\nu__-⋅q    A_\mu⋅W_\mu__+⋅W_\nu__+⋅Z_\nu⋅q    A_\mu
#  + ──────────────────────────────── + ──────────────────────────────── - ─────
#                   2                           2⋅tan(\theta_W)                2
#
#
#          2        2
# ⋅W_\nu__+ ⋅Z_\mu⋅q    A_\mu⋅W_\nu__+⋅\partial_\mu W_\nu__+⋅q   A_\mu⋅W_\nu__+⋅
# ─────────────────── + ────────────────────────────────────── + ───────────────
# ⋅tan(\theta_W)                          4
#
#
#
# \partial_\mu W_\nu__-⋅q   √2⋅A_\mu⋅W_\nu__+⋅\partial_\mu W_\nu__2⋅q   A_\mu⋅W_
# ...

# %% [markdown]
# This is a complicated expression, but as expected from the form of the vector boson Lagrangian, the theory predicts tri and quartic boson interactions.

# %% [markdown]
# ### The Lagrangian of Quantum Chromodynamics (QCD)
# The Lagrangian of quantum chromodynamics (QCD), for the 1st generation of particles, is given by
#
# \begin{align*}
#     {\cal L}_\textrm{QCD} & = \overline{U} i \gamma^\mu \left(\partial_\mu \mathbf{1} + i g_3 \frac{\boldsymbol{\lambda}}{2} \cdot \mathbf{G}_\mu\right) U + \overline{D} i \gamma^\mu \left(\partial_\mu \mathbf{1} + i g_3 \frac{\boldsymbol{\lambda}}{2} \cdot \mathbf{G}_\mu\right) D \\
#     & - \frac{1}{4} \mathbf{G}_{\mu\nu} \cdot \mathbf{G}^{\mu\nu}\\
#     \textrm{and } & \\
#     (\mathbf{G}_{\mu\nu})_a   & = (\partial_\mu \mathbf{G}_\nu)_a - (\partial_\nu \mathbf{G}_\mu)_a - g_3 \, f_{abc} G^b_\mu G^c_\nu,
# \end{align*}
#
# where $U$ and $D$, respectively, are the up and down quark field triplets each of whose components is associated with one of three quark colors. The
# $\lambda^a$ are the 8 Gell-Mann matrices each associated with one of the
# 8 gluon fields $G^a_\mu$, and $g_3$ is the strong coupling parameter. The quantities in parentheses are $3 \times 3$ matrices. The QCD Lagrangian is invariant under $SU(3)$ transformations and the numbers $f_{abc}$ are
# the structure constants of the group.
#
# When QCD is added to the GSW (electroweak) Lagrangian, thereby forming the Lagrangian of the __Standard Model__ (SM), the up and down quark fields acquire a 3-color index. Therefore, in the electroweak part of the Lagrangian each quark field will now carry a color index, in which case it is necessary to sum over the color indices in that part of the Lagrangian. Note that each quark field in the QCD Lagrangian is the sum of left-handed and right-handed fields.
#
# Since the SM is gauge invariant, in order to perform calculations, it is necessary to fix the definition of its bosonic (gauge) fields by choosing a gauge. Choosing a gauge is akin to choosing a coordinate system in that the predictions of the theory do not depend on the choice of gauge, at least in the limit of exact calculations. (In practice, calculations are done using perturbation theory. Consequently, depending on how the calculations are done there may be some residual, unphysical, gauge dependence in the predictions.) Unfortunately, choosing the gauge requires the addition of quite a bit of extra structure, involving unphysical fields called ghost fields, which makes what is otherwise an elegant structure much less so.
